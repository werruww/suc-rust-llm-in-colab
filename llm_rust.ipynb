# %% [markdown]
# https://huggingface.co/docs/text-embeddings-inference/main/en/local_cpu#step-1-install-rust

# %% [markdown]
# https://github.com/plaggy/rag-containers

# %% [markdown]
# https://github.com/rust-lang/rust
#
# https://www.rust-lang.org/tools/install
#
#
# https://rust-lang.guide/guide/learn-rust/index.html

# %% [markdown]
# https://users.rust-lang.org/

# %% [markdown]
# https://www.youtube.com/watch?v=KJgvUPXi3Fw

# %% [markdown]
# https://github.com/GeneralBots

# %%
# تنصيب Rust (الإصدار الليلي)
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y --default-toolchain nightly
# Out:
# info: downloading installer
# info: profile set to 'default'
# info: default host triple is x86_64-unknown-linux-gnu
# info: syncing channel updates for 'nightly-x86_64-unknown-linux-gnu'
# info: latest update on 2025-08-21, rust version 1.91.0-nightly (040a98af7 2025-08-20)
# info: downloading component 'cargo'
# info: downloading component 'clippy'
# info: downloading component 'rust-docs'
# info: downloading component 'rust-std'
#  28.0 MiB /  28.0 MiB (100 %)  18.8 MiB/s in  1s
# info: downloading component 'rustc'
#  80.2 MiB /  80.2 MiB (100 %)  49.0 MiB/s in  1s
# info: downloading component 'rustfmt'
# info: installing component 'cargo'
#  10.3 MiB /  10.3 MiB (100 %)   8.2 MiB/s in  1s
# info: installing component 'clippy'
# info: installing component 'rust-docs'
#  21.8 MiB /  21.8 MiB (100 %)   2.3 MiB/s in  9s
# info: installing component 'rust-std'
#  28.0 MiB /  28.0 MiB (100 %)   7.4 MiB/s in  4s
# info: installing component 'rustc'
# ...

# %%
import os
os.environ['PATH'] += ":/root/.cargo/bin"

# %%
# !rustc --version
# !cargo --version
# Out:
# rustc 1.91.0-nightly (040a98af7 2025-08-20)
# cargo 1.91.0-nightly (71eb84f21 2025-08-17)

# %%
# !cargo new my_rust_project
# Out:
#     Creating binary (application) `my_rust_project` package
# note: see more `Cargo.toml` keys and their definitions at https://doc.rust-lang.org/cargo/reference/manifest.html

# %%
# %cd /content/my_rust_project
# Out:
# /content/my_rust_project

# %%
# !cargo run
# Out:
#    Compiling my_rust_project v0.1.0 (/content/my_rust_project)
#     Finished `dev` profile [unoptimized + debuginfo] target(s) in 0.52s
#      Running `target/debug/my_rust_project`
# Hello, world!

# %%
# إنشاء ملف Rust
# %%writefile src/main.rs
fn main() {
    println!("aaaaaaaaaaaaaaaaaaaaa");
}

# %%
# %%writefile my_project/Cargo.toml
# [package]
# name = "my_project"
# version = "0.1.0"
# edition = "2021"
#
# [dependencies]
# serde = "1.0"  # مثال لمكتبة

# %% [markdown]
# https://github.com/graniet/llm

# %%
curl -fsSL https://ollama.com/install.sh | sh
nohup ollama serve &
ollama pull llama3:8b
ollama list

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !nohup ollama serve &
# !ollama pull llama3.2:3b
# Out:
# nohup: appending output to 'nohup.out'
# Error: ollama server not responding - could not connect to ollama server, run 'ollama serve' to start it

# %%
# !ollama pull llama3.2:3b

# %%
# !ollama list
# Out:
# NAME           ID              SIZE      MODIFIED
# llama3.2:3b    a80c4f17acd5    2.0 GB    7 minutes ago

# %% [markdown]
# https://github.com/graniet/llm

# %%
# %cd /content

# !git clone https://github.com/graniet/llm.git
# Out:
# /content
# Cloning into 'llm'...
# remote: Enumerating objects: 2082, done.
# remote: Counting objects: 100% (629/629), done.
# remote: Compressing objects: 100% (304/304), done.
# remote: Total 2082 (delta 398), reused 332 (delta 323), pack-reused 1453 (from 2)
# Receiving objects: 100% (2082/2082), 652.33 KiB | 5.39 MiB/s, done.
# Resolving deltas: 100% (1414/1414), done.

# %%
# %cd /content/llm
# Out:
# /content/llm

# %%
# %%writefile Cargo.toml
# [package]
# name = "llm"
# version = "1.3.3"
# edition = "2021"
#
# [dependencies]
# llm = { version = "1.3.3", features = ["openai", "anthropic", "ollama", "deepseek", "xai", "phind", "google", "groq", "mistral", "elevenlabs"] }
# Out:
# Overwriting Cargo.toml

# %%
# !llm
# Out:
# Error: "No provider specified. Use --provider, provider:model argument, or set a default provider with 'llm default <provider:model>'"

# %%
# !cargo install llm
# Out:
#     Updating crates.io index
# ...
#   Downloaded llm v1.3.3
#   Installing llm v1.3.3
#     Updating crates.io index
#      Locking 226 packages to latest compatible versions
#       Adding axum v0.7.9 (available: v0.8.4)
#       Adding rustyline v15.0.0 (available: v17.0.1)
#       Adding tower-http v0.5.2 (available: v0.6.6)
# ...
#   Downloaded anstyle-parse v0.2.7
#   Downloaded anstyle v1.0.11
#   Downloaded autocfg v1.5.0
#   Downloaded async-trait v0.1.89
#   Downloaded option-ext v0.2.0
#   Downloaded pkg-config v0.3.32
#   Downloaded hyper-tls v0.6.0
#   Downloaded num-traits v0.2.19
#   Downloaded http-body v1.0.1
#   Downloaded pin-utils v0.1.0
#   Downloaded quote v1.0.40
#   Downloaded rustversion v1.0.22
#   Downloaded icu_provider v2.0.0
#   Downloaded rustls-pki-types v1.12.0
#   Downloaded unicase v2.8.1
#   Downloaded yoke-derive v0.8.0
#   Downloaded memchr v2.7.5
#   Downloaded zerovec-derive v0.11.1
#   Downloaded zeroize v1.8.1
#   Downloaded yoke v0.8.0
# ...

# %%
# !cargo run /content/llm/examples/ollama_example.rs
# Out:
#     Updating crates.io index
# error: failed to select a version for `llm`.
#     ... required by package `llm v1.3.3 (/content/llm)`
# versions that meet the requirements `^1.3.3` are: 1.3.3
#
# package `llm` depends on `llm` with feature `Elevenlabs` but `llm` does not have that feature.
#  package `llm` does have feature `elevenlabs`
#
#
# failed to select a version for `llm` which could resolve this conflict

# %%
# !ls /content/llm/examples/
# Out:
# agent_builder_example.rs
# anthropic_example.rs
# anthropic_streaming_example.rs
# anthropic_thinking_example.rs
# anthropic_vision_example.rs
# api_deepclaude_example.rs
# api_example.rs
# azure_openai_embedding_example.rs
# azure_openai_example.rs
# azure_openai_tool_calling_example.rs
# chain_audio_text_example.rs
# chain_example.rs
# chain_logging_example.rs
# cohere_example.rs
# deepclaude_pipeline_example.rs
# deepseek_example.rs
# dummy.pdf
# elevenlabs_stt_example.rs
# elevenlabs_tts_example.rs
# embedding_example.rs
# evaluation_example.rs
# evaluator_parallel_example.rs
# google_embedding_example.rs
# google_example.rs
# google_image.rs
# google_pdf.rs
# google_streaming_example.rs
# google_structured_output_example.rs
# google_tool_calling_example.rs
# groq_example.rs
# image001.jpg
# json_schema_nested_example.rs
# memory_example.rs
# memory_share_example.rs
# mistral_example.rs
# model_listing_example.rs
# multi_backend_example.rs
# ...

# %%
# %cd /content/llm
# !cargo run --example ollama_example
# Out:
# /content/llm
#     Updating crates.io index
# error: failed to select a version for `llm`.
#     ... required by package `llm v1.3.3 (/content/llm)`
# versions that meet the requirements `^1.3.3` are: 1.3.3
#
# package `llm` depends on `llm` with feature `Elevenlabs` but `llm` does not have that feature.
#  package `llm` does have feature `elevenlabs`
#
#
# failed to select a version for `llm` which could resolve this conflict

# %%
# !ollama list
# Out:
# NAME           ID              SIZE      MODIFIED
# llama3.2:3b    a80c4f17acd5    2.0 GB    20 minutes ago

# %%
# %cd /content/llm
# Out:
# /content/llm

# %%
# %%writefile Cargo.toml
# [package]
# name = "llm"
# version = "1.3.3"
# edition = "2021"
#
# [dependencies]
# llm = { version = "1.3.3", features = ["openai", "anthropic", "ollama", "deepseek", "xai", "phind", "google", "groq", "mistral", "elevenlabs"] }
# Out:
# Overwriting Cargo.toml

# %%
# !llm --provider ollama llama3.2:3b "Hello, Ollama!"
# Out:
# Error: "Invalid provider: Invalid Request: Unknown LLM backend: Hello, Ollama!"

# %%
# !llm --version
# Out:
# Error: "No provider specified. Use --provider, provider:model argument, or set a default provider with 'llm default <provider:model>'"

# %%
# %cd /content/llm
# !cargo clean
# !cargo build --example ollama_example
# Out:
# /content/llm
#      Removed 1384 files, 718.8MiB total
#    Compiling proc-macro2 v1.0.95
#    Compiling unicode-ident v1.0.14
#    Compiling autocfg v1.4.0
#    Compiling libc v0.2.169
#    Compiling quote v1.0.38
#    Compiling syn v2.0.101
#    Compiling cfg-if v1.0.0
#    Compiling smallvec v1.13.2
#    Compiling memchr v2.7.4
#    Compiling pin-project-lite v0.2.15
#    Compiling futures-core v0.3.31
#    Compiling slab v0.4.9
#    Compiling itoa v1.0.14
#    Compiling futures-sink v0.3.31
#    Compiling bytes v1.9.0
#    Compiling stable_deref_trait v1.2.0
#    Compiling futures-channel v0.3.31
#    Compiling lock_api v0.4.12
#    Compiling futures-task v0.3.31
#    Compiling synstructure v0.13.1
#    Compiling pin-utils v0.1.0
#    Compiling futures-io v0.3.31
#    Compiling parking_lot_core v0.9.10
#    Compiling scopeguard v1.2.0
#    Compiling shlex v1.3.0
#    Compiling once_cell v1.20.2
#    Compiling cc v1.2.7
#    Compiling zerofrom-derive v0.1.5
# ...

# %%
# !cargo run --example ollama_example
# Out:
#    Compiling llm v1.3.3 (/content/llm)
# error[E0432]: unresolved import `async_trait`
#   --> src/lib.rs:17:9
#    |
# 17 | pub use async_trait::async_trait;
#    |         ^^^^^^^^^^^ use of unresolved module or unlinked crate `async_trait`
#    |
#    = help: if you wanted to use a crate named `async_trait`, use `cargo add async_trait` to add it to your `Cargo.toml`
#
# error[E0433]: failed to resolve: use of unresolved module or unlinked crate `tokio`
#   --> src/builder.rs:17:5
#    |
# 17 | use tokio::sync::RwLock;
#    |     ^^^^^ use of unresolved module or unlinked crate `tokio`
#    |
#    = help: if you wanted to use a crate named `tokio`, use `cargo add tokio` to add it to your `Cargo.toml`
#
# error[E0432]: unresolved import `serde`
#   --> src/lib.rs:20:5
#    |
# 20 | use serde::{Deserialize, Serialize};
#    |     ^^^^^ use of unresolved module or unlinked crate `serde`
#    |
# ...

# %%
# %%writefile Cargo.toml
# [package]
# name = "llm"
# version = "1.3.3"
# edition = "2021"
#
# [dependencies]
# llm = { version = "1.3.3", features = ["openai", "anthropic", "ollama", "deepseek", "xai", "phind", "google", "groq", "mistral", "elevenlabs"] }
# Out:
# Overwriting Cargo.toml

# %%
# %cd /content/llm
# Out:
# /content/llm

# %%
# %cd /content/llm
# !cargo run --example ollama_example
# Out:
# /content/llm
#     Updating crates.io index
#      Locking 1 package to latest compatible version
#       Adding llm v1.3.3
# ...
#   Downloaded anstream v0.6.18
#   Downloaded anstyle-query v1.1.2
#   Downloaded autocfg v1.4.0
#   Downloaded utf16_iter v1.0.5
#   Downloaded bitflags v2.6.0
#   Downloaded unicode-ident v1.0.14
#   Downloaded cc v1.2.7
#   Downloaded openssl-sys v0.9.104
#   Downloaded yoke v0.7.5
#   Downloaded writeable v0.5.5
#   Downloaded zerofrom v0.1.5
#   Downloaded cfg-if v1.0.0
#   Downloaded tracing-core v0.1.33
#   Downloaded tinystr v0.7.6
#   Downloaded zerovec-derive v0.10.3
#   Downloaded rustversion v1.0.19
#   Downloaded uuid v1.12.1
#   Downloaded zerovec v0.10.4
#   Downloaded serde_json v1.0.134
#   Downloaded openssl v0.10.68
#   Downloaded icu_properties v1.5.1
#   Downloaded tokio v1.42.0
#   Downloaded hyper-util v0.1.10
#   Downloaded icu_normalizer_data v1.5.0
#   Downloaded mio v1.0.3
#   Downloaded idna v1.0.3
#   Downloaded hyper v1.5.2
# ...

# %%
# !echo "Hello World" | llm
# Out:
# Error: "No provider specified. Use --provider, provider:model argument, or set a default provider with 'llm default <provider:model>'"

# %%
# !llm --provider ollama --model llama3.2:3b --temperature 0.7
# Out:
# llm - Interactive Chat
# Provider: ollama
# Type 'exit' to quit
# ──────────────────────────────────────────────────
# hi
# > Assistant: How can I assist you today?
# ──────────────────────────────────────────────────
# who is ai?
# > Assistant: AI stands for Artificial Intelligence, which refers to the simulation of human intelligence in machines that are programmed to think and learn like humans. The term "Artificial" means that it's a man-made creation, while "Intelligence" refers to its ability to perform tasks that typically require human intelligence.
#
# In other words, AI is a computer system that can perform tasks that would normally require human intelligence, such as:
#
# * Learning from data
# * Making decisions
# * Recognizing patterns
# * Understanding language
#
# There are many types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition or language translation.
# ...

# %%
# !ollama pull gpt-oss:20b
